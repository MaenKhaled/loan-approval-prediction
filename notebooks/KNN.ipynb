# %%
import pandas as pd

df = pd.read_csv('data/clean/cleaned_loan_data.csv')

# %%
df.head()
# Out:
#    loan_id  no_of_dependents     education self_employed  income_annum  \
# 0        1                 2      graduate            no       9600000
# 1        2                 0  not-graduate           yes       4100000
# 2        3                 3      graduate            no       9100000
# 3        4                 3      graduate            no       8200000
# 4        5                 5  not-graduate           yes       9800000
#
#    loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0     29900000         12          778                   2400000
# 1     12200000          8          417                   2700000
# 2     29700000         20          506                   7100000
# 3     30700000          8          467                  18200000
# 4     24200000         20          382                  12400000
#
#    commercial_assets_value  luxury_assets_value  bank_asset_value loan_status
# 0                 17600000             22700000           8000000    approved
# 1                  2200000              8800000           3300000    rejected
# 2                  4500000             33300000          12800000    rejected
# 3                  3300000             23300000           7900000    rejected
# 4                  8200000             29400000           5000000    rejected

# %%
df['education'] = df['education'].astype(str).str.lower().str.strip().map({'graduate': 1, 'not-graduate': 0})
df['self_employed'] = df['self_employed'].astype(str).str.lower().str.strip().map({'yes': 1, 'no': 0})
df['loan_status'] = df['loan_status'].astype(str).str.lower().str.strip().map({'approved': 1, 'rejected': 0})

# Check results
print(df[['education', 'self_employed', 'loan_status']].head())
# Out:
#    education  self_employed  loan_status
# 0          1              0            1
# 1          0              1            0
# 2          1              0            0
# 3          1              0            0
# 4          0              1            0

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, accuracy_score
from scipy.stats import t
import time

# Load and preprocess
X = df.drop(columns=["loan_id", "loan_status"])
y = df["loan_status"]

X_encoded = pd.get_dummies(X, drop_first=True)


X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=123)

scaler = StandardScaler()
X_train_norm_df = scaler.fit_transform(X_train)
X_test_norm_df = scaler.transform(X_test)

# Parameter grid for KNN
parameter_grid = {
    "n_neighbors": [int(x) for x in np.linspace(start=2, stop=30, num=15)],
    "weights": ['uniform', 'distance'],
    "p": [1, 2]
}

knn = KNeighborsClassifier()

folds = 5
confidence_level = 0.95

rs = RandomizedSearchCV(knn, param_distributions=parameter_grid, n_iter=16, cv=folds, verbose=10, random_state=123)

start_time = time.time()
rs.fit(X_train_norm_df, y_train)
end_time = time.time()

print("\n")
print(f"Time taken to find the best combination of hyperparameters: {end_time - start_time:.4f} seconds")
print("\n")
print(f"The best combination of hyperparameters has been: {rs.best_params_}")
print(f"The cross-validated accuracy is: {rs.best_score_:.4f}")

# Confidence interval
results_rs_df = pd.DataFrame(rs.cv_results_).sort_values(by="mean_test_score", ascending=False)
rs_mean_score = results_rs_df.iloc[0, -3]
rs_sem = results_rs_df.iloc[0, -2] / np.sqrt(folds)

rs_tc = t.ppf(1 - ((1 - confidence_level) / 2), df=folds - 1)
rs_lower_bound = rs_mean_score - (rs_tc * rs_sem)
rs_upper_bound = rs_mean_score + (rs_tc * rs_sem)

print(f"The accuracy confidence interval for the best combination of hyperparameters is: \
({rs_lower_bound:.4f}, {rs_mean_score:.4f}, {rs_upper_bound:.4f})")

# Evaluate on test set
best_model = rs.best_estimator_
y_pred_test_df = best_model.predict(X_test_norm_df)

print("\n")
print("Classification Report on Test Set:")
print(classification_report(y_test, y_pred_test_df))
print(f"Test Accuracy: {accuracy_score(y_test, y_pred_test_df):.4f}")
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5; 1/16] START n_neighbors=14, p=1, weights=uniform.......................
# [CV 1/5; 1/16] END n_neighbors=14, p=1, weights=uniform;, score=0.918 total time=   0.0s
# [CV 2/5; 1/16] START n_neighbors=14, p=1, weights=uniform.......................
# [CV 2/5; 1/16] END n_neighbors=14, p=1, weights=uniform;, score=0.921 total time=   0.0s
# [CV 3/5; 1/16] START n_neighbors=14, p=1, weights=uniform.......................
# [CV 3/5; 1/16] END n_neighbors=14, p=1, weights=uniform;, score=0.900 total time=   0.0s
# [CV 4/5; 1/16] START n_neighbors=14, p=1, weights=uniform.......................
# [CV 4/5; 1/16] END n_neighbors=14, p=1, weights=uniform;, score=0.922 total time=   0.0s
# [CV 5/5; 1/16] START n_neighbors=14, p=1, weights=uniform.......................
# [CV 5/5; 1/16] END n_neighbors=14, p=1, weights=uniform;, score=0.906 total time=   0.0s
# [CV 1/5; 2/16] START n_neighbors=20, p=2, weights=distance......................
# [CV 1/5; 2/16] END n_neighbors=20, p=2, weights=distance;, score=0.905 total time=   0.0s
# [CV 2/5; 2/16] START n_neighbors=20, p=2, weights=distance......................
# [CV 2/5; 2/16] END n_neighbors=20, p=2, weights=distance;, score=0.915 total time=   0.0s
# [CV 3/5; 2/16] START n_neighbors=20, p=2, weights=distance......................
# [CV 3/5; 2/16] END n_neighbors=20, p=2, weights=distance;, score=0.895 total time=   0.0s
# [CV 4/5; 2/16] START n_neighbors=20, p=2, weights=distance......................
# [CV 4/5; 2/16] END n_neighbors=20, p=2, weights=distance;, score=0.911 total time=   0.0s
# [CV 5/5; 2/16] START n_neighbors=20, p=2, weights=distance......................
# [CV 5/5; 2/16] END n_neighbors=20, p=2, weights=distance;, score=0.911 total time=   0.0s
# [CV 1/5; 3/16] START n_neighbors=8, p=2, weights=distance.......................
# [CV 1/5; 3/16] END n_neighbors=8, p=2, weights=distance;, score=0.898 total time=   0.0s
# [CV 2/5; 3/16] START n_neighbors=8, p=2, weights=distance.......................
# [CV 2/5; 3/16] END n_neighbors=8, p=2, weights=distance;, score=0.908 total time=   0.0s
# [CV 3/5; 3/16] START n_neighbors=8, p=2, weights=distance.......................
# [CV 3/5; 3/16] END n_neighbors=8, p=2, weights=distance;, score=0.898 total time=   0.0s
# [CV 4/5; 3/16] START n_neighbors=8, p=2, weights=distance.......................
# [CV 4/5; 3/16] END n_neighbors=8, p=2, weights=distance;, score=0.895 total time=   0.0s
# [CV 5/5; 3/16] START n_neighbors=8, p=2, weights=distance.......................
# [CV 5/5; 3/16] END n_neighbors=8, p=2, weights=distance;, score=0.908 total time=   0.0s
# [CV 1/5; 4/16] START n_neighbors=16, p=2, weights=distance......................
# [CV 1/5; 4/16] END n_neighbors=16, p=2, weights=distance;, score=0.902 total time=   0.0s
# [CV 2/5; 4/16] START n_neighbors=16, p=2, weights=distance......................
# [CV 2/5; 4/16] END n_neighbors=16, p=2, weights=distance;, score=0.915 total time=   0.0s
# [CV 3/5; 4/16] START n_neighbors=16, p=2, weights=distance......................
# [CV 3/5; 4/16] END n_neighbors=16, p=2, weights=distance;, score=0.899 total time=   0.0s
# [CV 4/5; 4/16] START n_neighbors=16, p=2, weights=distance......................
# [CV 4/5; 4/16] END n_neighbors=16, p=2, weights=distance;, score=0.905 total time=   0.0s
# [CV 5/5; 4/16] START n_neighbors=16, p=2, weights=distance......................
# [CV 5/5; 4/16] END n_neighbors=16, p=2, weights=distance;, score=0.908 total time=   0.0s
# [CV 1/5; 5/16] START n_neighbors=22, p=2, weights=distance......................
# [CV 1/5; 5/16] END n_neighbors=22, p=2, weights=distance;, score=0.905 total time=   0.0s
# [CV 2/5; 5/16] START n_neighbors=22, p=2, weights=distance......................
# [CV 2/5; 5/16] END n_neighbors=22, p=2, weights=distance;, score=0.919 total time=   0.0s
# [CV 3/5; 5/16] START n_neighbors=22, p=2, weights=distance......................
# [CV 3/5; 5/16] END n_neighbors=22, p=2, weights=distance;, score=0.898 total time=   0.0s
# [CV 4/5; 5/16] START n_neighbors=22, p=2, weights=distance......................
# [CV 4/5; 5/16] END n_neighbors=22, p=2, weights=distance;, score=0.914 total time=   0.0s
# [CV 5/5; 5/16] START n_neighbors=22, p=2, weights=distance......................
# [CV 5/5; 5/16] END n_neighbors=22, p=2, weights=distance;, score=0.911 total time=   0.0s
# [CV 1/5; 6/16] START n_neighbors=28, p=1, weights=uniform.......................
# [CV 1/5; 6/16] END n_neighbors=28, p=1, weights=uniform;, score=0.918 total time=   0.0s
# [CV 2/5; 6/16] START n_neighbors=28, p=1, weights=uniform.......................
# [CV 2/5; 6/16] END n_neighbors=28, p=1, weights=uniform;, score=0.925 total time=   0.0s
# [CV 3/5; 6/16] START n_neighbors=28, p=1, weights=uniform.......................
# [CV 3/5; 6/16] END n_neighbors=28, p=1, weights=uniform;, score=0.919 total time=   0.0s
# [CV 4/5; 6/16] START n_neighbors=28, p=1, weights=uniform.......................
# [CV 4/5; 6/16] END n_neighbors=28, p=1, weights=uniform;, score=0.928 total time=   0.0s
# [CV 5/5; 6/16] START n_neighbors=28, p=1, weights=uniform.......................
# [CV 5/5; 6/16] END n_neighbors=28, p=1, weights=uniform;, score=0.925 total time=   0.0s
# [CV 1/5; 7/16] START n_neighbors=10, p=2, weights=uniform.......................
# [CV 1/5; 7/16] END n_neighbors=10, p=2, weights=uniform;, score=0.900 total time=   0.0s
# [CV 2/5; 7/16] START n_neighbors=10, p=2, weights=uniform.......................
# [CV 2/5; 7/16] END n_neighbors=10, p=2, weights=uniform;, score=0.908 total time=   0.0s
# [CV 3/5; 7/16] START n_neighbors=10, p=2, weights=uniform.......................
# [CV 3/5; 7/16] END n_neighbors=10, p=2, weights=uniform;, score=0.908 total time=   0.0s
# [CV 4/5; 7/16] START n_neighbors=10, p=2, weights=uniform.......................
# [CV 4/5; 7/16] END n_neighbors=10, p=2, weights=uniform;, score=0.898 total time=   0.0s
# [CV 5/5; 7/16] START n_neighbors=10, p=2, weights=uniform.......................
# [CV 5/5; 7/16] END n_neighbors=10, p=2, weights=uniform;, score=0.905 total time=   0.0s
# [CV 1/5; 8/16] START n_neighbors=22, p=1, weights=uniform.......................
# [CV 1/5; 8/16] END n_neighbors=22, p=1, weights=uniform;, score=0.912 total time=   0.0s
# [CV 2/5; 8/16] START n_neighbors=22, p=1, weights=uniform.......................
# [CV 2/5; 8/16] END n_neighbors=22, p=1, weights=uniform;, score=0.921 total time=   0.0s
# [CV 3/5; 8/16] START n_neighbors=22, p=1, weights=uniform.......................
# [CV 3/5; 8/16] END n_neighbors=22, p=1, weights=uniform;, score=0.918 total time=   0.0s
# [CV 4/5; 8/16] START n_neighbors=22, p=1, weights=uniform.......................
# [CV 4/5; 8/16] END n_neighbors=22, p=1, weights=uniform;, score=0.919 total time=   0.0s
# [CV 5/5; 8/16] START n_neighbors=22, p=1, weights=uniform.......................
# [CV 5/5; 8/16] END n_neighbors=22, p=1, weights=uniform;, score=0.918 total time=   0.0s
# [CV 1/5; 9/16] START n_neighbors=28, p=2, weights=distance......................
# [CV 1/5; 9/16] END n_neighbors=28, p=2, weights=distance;, score=0.898 total time=   0.0s
# [CV 2/5; 9/16] START n_neighbors=28, p=2, weights=distance......................
# [CV 2/5; 9/16] END n_neighbors=28, p=2, weights=distance;, score=0.919 total time=   0.0s
# [CV 3/5; 9/16] START n_neighbors=28, p=2, weights=distance......................
# [CV 3/5; 9/16] END n_neighbors=28, p=2, weights=distance;, score=0.903 total time=   0.0s
# [CV 4/5; 9/16] START n_neighbors=28, p=2, weights=distance......................
# [CV 4/5; 9/16] END n_neighbors=28, p=2, weights=distance;, score=0.906 total time=   0.0s
# [CV 5/5; 9/16] START n_neighbors=28, p=2, weights=distance......................
# [CV 5/5; 9/16] END n_neighbors=28, p=2, weights=distance;, score=0.919 total time=   0.0s
# [CV 1/5; 10/16] START n_neighbors=8, p=1, weights=distance......................
# [CV 1/5; 10/16] END n_neighbors=8, p=1, weights=distance;, score=0.912 total time=   0.0s
# [CV 2/5; 10/16] START n_neighbors=8, p=1, weights=distance......................
# [CV 2/5; 10/16] END n_neighbors=8, p=1, weights=distance;, score=0.915 total time=   0.0s
# [CV 3/5; 10/16] START n_neighbors=8, p=1, weights=distance......................
# [CV 3/5; 10/16] END n_neighbors=8, p=1, weights=distance;, score=0.900 total time=   0.0s
# [CV 4/5; 10/16] START n_neighbors=8, p=1, weights=distance......................
# [CV 4/5; 10/16] END n_neighbors=8, p=1, weights=distance;, score=0.899 total time=   0.0s
# [CV 5/5; 10/16] START n_neighbors=8, p=1, weights=distance......................
# [CV 5/5; 10/16] END n_neighbors=8, p=1, weights=distance;, score=0.887 total time=   0.0s
# [CV 1/5; 11/16] START n_neighbors=14, p=2, weights=uniform......................
# [CV 1/5; 11/16] END n_neighbors=14, p=2, weights=uniform;, score=0.911 total time=   0.0s
# [CV 2/5; 11/16] START n_neighbors=14, p=2, weights=uniform......................
# [CV 2/5; 11/16] END n_neighbors=14, p=2, weights=uniform;, score=0.917 total time=   0.0s
# [CV 3/5; 11/16] START n_neighbors=14, p=2, weights=uniform......................
# [CV 3/5; 11/16] END n_neighbors=14, p=2, weights=uniform;, score=0.890 total time=   0.0s
# [CV 4/5; 11/16] START n_neighbors=14, p=2, weights=uniform......................
# [CV 4/5; 11/16] END n_neighbors=14, p=2, weights=uniform;, score=0.906 total time=   0.0s
# [CV 5/5; 11/16] START n_neighbors=14, p=2, weights=uniform......................
# [CV 5/5; 11/16] END n_neighbors=14, p=2, weights=uniform;, score=0.896 total time=   0.0s
# [CV 1/5; 12/16] START n_neighbors=14, p=2, weights=distance.....................
# [CV 1/5; 12/16] END n_neighbors=14, p=2, weights=distance;, score=0.899 total time=   0.0s
# [CV 2/5; 12/16] START n_neighbors=14, p=2, weights=distance.....................
# [CV 2/5; 12/16] END n_neighbors=14, p=2, weights=distance;, score=0.914 total time=   0.0s
# [CV 3/5; 12/16] START n_neighbors=14, p=2, weights=distance.....................
# [CV 3/5; 12/16] END n_neighbors=14, p=2, weights=distance;, score=0.895 total time=   0.0s
# [CV 4/5; 12/16] START n_neighbors=14, p=2, weights=distance.....................
# [CV 4/5; 12/16] END n_neighbors=14, p=2, weights=distance;, score=0.900 total time=   0.0s
# [CV 5/5; 12/16] START n_neighbors=14, p=2, weights=distance.....................
# [CV 5/5; 12/16] END n_neighbors=14, p=2, weights=distance;, score=0.900 total time=   0.0s
# [CV 1/5; 13/16] START n_neighbors=28, p=2, weights=uniform......................
# [CV 1/5; 13/16] END n_neighbors=28, p=2, weights=uniform;, score=0.900 total time=   0.0s
# [CV 2/5; 13/16] START n_neighbors=28, p=2, weights=uniform......................
# [CV 2/5; 13/16] END n_neighbors=28, p=2, weights=uniform;, score=0.921 total time=   0.0s
# [CV 3/5; 13/16] START n_neighbors=28, p=2, weights=uniform......................
# [CV 3/5; 13/16] END n_neighbors=28, p=2, weights=uniform;, score=0.909 total time=   0.0s
# [CV 4/5; 13/16] START n_neighbors=28, p=2, weights=uniform......................
# [CV 4/5; 13/16] END n_neighbors=28, p=2, weights=uniform;, score=0.908 total time=   0.0s
# [CV 5/5; 13/16] START n_neighbors=28, p=2, weights=uniform......................
# [CV 5/5; 13/16] END n_neighbors=28, p=2, weights=uniform;, score=0.922 total time=   0.0s
# [CV 1/5; 14/16] START n_neighbors=12, p=2, weights=distance.....................
# [CV 1/5; 14/16] END n_neighbors=12, p=2, weights=distance;, score=0.903 total time=   0.0s
# [CV 2/5; 14/16] START n_neighbors=12, p=2, weights=distance.....................
# [CV 2/5; 14/16] END n_neighbors=12, p=2, weights=distance;, score=0.914 total time=   0.0s
# [CV 3/5; 14/16] START n_neighbors=12, p=2, weights=distance.....................
# [CV 3/5; 14/16] END n_neighbors=12, p=2, weights=distance;, score=0.896 total time=   0.0s
# [CV 4/5; 14/16] START n_neighbors=12, p=2, weights=distance.....................
# [CV 4/5; 14/16] END n_neighbors=12, p=2, weights=distance;, score=0.900 total time=   0.0s
# [CV 5/5; 14/16] START n_neighbors=12, p=2, weights=distance.....................
# [CV 5/5; 14/16] END n_neighbors=12, p=2, weights=distance;, score=0.905 total time=   0.0s
# [CV 1/5; 15/16] START n_neighbors=6, p=2, weights=distance......................
# [CV 1/5; 15/16] END n_neighbors=6, p=2, weights=distance;, score=0.886 total time=   0.0s
# [CV 2/5; 15/16] START n_neighbors=6, p=2, weights=distance......................
# [CV 2/5; 15/16] END n_neighbors=6, p=2, weights=distance;, score=0.912 total time=   0.0s
# [CV 3/5; 15/16] START n_neighbors=6, p=2, weights=distance......................
# [CV 3/5; 15/16] END n_neighbors=6, p=2, weights=distance;, score=0.893 total time=   0.0s
# [CV 4/5; 15/16] START n_neighbors=6, p=2, weights=distance......................
# [CV 4/5; 15/16] END n_neighbors=6, p=2, weights=distance;, score=0.895 total time=   0.0s
# [CV 5/5; 15/16] START n_neighbors=6, p=2, weights=distance......................
# [CV 5/5; 15/16] END n_neighbors=6, p=2, weights=distance;, score=0.902 total time=   0.0s
# [CV 1/5; 16/16] START n_neighbors=2, p=1, weights=uniform.......................
# [CV 1/5; 16/16] END n_neighbors=2, p=1, weights=uniform;, score=0.873 total time=   0.0s
# [CV 2/5; 16/16] START n_neighbors=2, p=1, weights=uniform.......................
# [CV 2/5; 16/16] END n_neighbors=2, p=1, weights=uniform;, score=0.845 total time=   0.0s
# [CV 3/5; 16/16] START n_neighbors=2, p=1, weights=uniform.......................
# [CV 3/5; 16/16] END n_neighbors=2, p=1, weights=uniform;, score=0.845 total time=   0.0s
# [CV 4/5; 16/16] START n_neighbors=2, p=1, weights=uniform.......................
# [CV 4/5; 16/16] END n_neighbors=2, p=1, weights=uniform;, score=0.842 total time=   0.0s
# [CV 5/5; 16/16] START n_neighbors=2, p=1, weights=uniform.......................
# [CV 5/5; 16/16] END n_neighbors=2, p=1, weights=uniform;, score=0.854 total time=   0.0s
#
#
# Time taken to find the best combination of hyperparameters: 0.7632 seconds
#
#
# The best combination of hyperparameters has been: {'weights': 'uniform', 'p': 1, 'n_neighbors': 28}
# The cross-validated accuracy is: 0.9233
# The accuracy confidence interval for the best combination of hyperparameters is: (0.9185, 0.9233, 0.9281)
#
#
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88       350
#            1       0.91      0.92      0.92       504
#
#     accuracy                           0.90       854
#    macro avg       0.90      0.90      0.90       854
# weighted avg       0.90      0.90      0.90       854
#
# Test Accuracy: 0.9005
